# %%
import pandas as pd
from apyori import apriori
import numpy as np

# %%
data=pd.read_csv('store_data.csv',header=None)

# %%
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
data.shape
# Out:
# (7501, 20)

# %%
type(data.iloc[3,3])
# Out:
# float

# %%
ls=[]
for i in range(0,7501):
    d=data.iloc[i,:]
    items=[]
    for i in d:
        if(str(i)!="nan"):
            items.append(i)
    ls.append(items)
len(ls)
# Out:
# 7501

# %%
association_rules=apriori(ls,min_support=0.0045,min_confidence=0.2,min_lift=3.0,max_length=3)
association_results=list(association_rules)
print(len(association_results))
# Out:
# 23

# %%
association_results[1].items
# Out:
# frozenset({'escalope', 'mushroom cream sauce'})

# %%
#items,antecedent,consequent,support,confidence,lift
it=[]
support_value=[]
antecedents=[]
consequents=[]
confidence=[]
lift=[]
for i in range(0,23):
    it.append(association_results[i].items)
    support_value.append(association_results[i].support)
    for j in range(0,1):
        antecedents.append(association_results[i].ordered_statistics[j].items_base)
        consequents.append(association_results[i].ordered_statistics[j].items_add)
        confidence.append(association_results[i].ordered_statistics[j].confidence)
        lift.append(association_results[i].ordered_statistics[j].lift)

# %%
table=pd.DataFrame({"Itemset":it,"Antecedent":antecedents,"Consequent":consequents,"Support":support_value,
                    "Confidence":confidence,"Lift":lift})

# %%
table
# Out:
#                                         Itemset  \
# 0                        (chicken, light cream)
# 1              (mushroom cream sauce, escalope)
# 2                             (pasta, escalope)
# 3                  (ground beef, herb & pepper)
# 4                   (ground beef, tomato sauce)
# 5                (whole wheat pasta, olive oil)
# 6                               (shrimp, pasta)
# 7        (frozen vegetables, shrimp, chocolate)
# 8         (ground beef, cooking oil, spaghetti)
# 9   (frozen vegetables, spaghetti, ground beef)
# 10         (frozen vegetables, olive oil, milk)
# 11   (frozen vegetables, shrimp, mineral water)
# 12    (frozen vegetables, spaghetti, olive oil)
# 13       (frozen vegetables, shrimp, spaghetti)
# 14     (frozen vegetables, spaghetti, tomatoes)
# 15      (ground beef, grated cheese, spaghetti)
# 16  (ground beef, mineral water, herb & pepper)
# 17      (ground beef, spaghetti, herb & pepper)
# 18               (ground beef, olive oil, milk)
# 19             (ground beef, shrimp, spaghetti)
# 20                 (spaghetti, olive oil, milk)
# 21             (mineral water, olive oil, soup)
# 22             (pancakes, spaghetti, olive oil)
#
#                         Antecedent           Consequent   Support  Confidence  \
# 0                    (light cream)            (chicken)  0.004533    0.290598
# 1           (mushroom cream sauce)           (escalope)  0.005733    0.300699
# 2                          (pasta)           (escalope)  0.005866    0.372881
# 3                  (herb & pepper)        (ground beef)  0.015998    0.323450
# 4                   (tomato sauce)        (ground beef)  0.005333    0.377358
# 5              (whole wheat pasta)          (olive oil)  0.007999    0.271493
# 6                          (pasta)             (shrimp)  0.005066    0.322034
# 7   (frozen vegetables, chocolate)             (shrimp)  0.005333    0.232558
# 8       (ground beef, cooking oil)          (spaghetti)  0.004799    0.571429
# 9   (frozen vegetables, spaghetti)        (ground beef)  0.008666    0.311005
# 10       (frozen vegetables, milk)          (olive oil)  0.004799    0.203390
# 11         (mineral water, shrimp)  (frozen vegetables)  0.007199    0.305085
# 12  (frozen vegetables, spaghetti)          (olive oil)  0.005733    0.205742
# 13  (frozen vegetables, spaghetti)             (shrimp)  0.005999    0.215311
# 14  (frozen vegetables, spaghetti)           (tomatoes)  0.006666    0.239234
# 15      (grated cheese, spaghetti)        (ground beef)  0.005333    0.322581
# 16  (mineral water, herb & pepper)        (ground beef)  0.006666    0.390625
# 17      (spaghetti, herb & pepper)        (ground beef)  0.006399    0.393443
# 18             (ground beef, milk)          (olive oil)  0.004933    0.224242
# 19           (ground beef, shrimp)          (spaghetti)  0.005999    0.523256
# 20               (spaghetti, milk)          (olive oil)  0.007199    0.203008
# 21           (mineral water, soup)          (olive oil)  0.005199    0.225434
# 22           (pancakes, spaghetti)          (olive oil)  0.005066    0.201058
#
#         Lift
# 0   4.843951
# 1   3.790833
# 2   4.700812
# 3   3.291994
# 4   3.840659
# 5   4.122410
# 6   4.506672
# 7   3.254512
# 8   3.281995
# 9   3.165328
# 10  3.088314
# 11  3.200616
# 12  3.124024
# 13  3.013149
# 14  3.498046
# 15  3.283144
# 16  3.975683
# 17  4.004360
# 18  3.404944
# 19  3.005315
# 20  3.082509
# 21  3.423030
# 22  3.052910
