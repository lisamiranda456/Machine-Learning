# %% [markdown]
# ### Importing required Libraries.

# %%
import pandas as pd
import numpy as np
from surprise import KNNWithMeans,Dataset,accuracy,Reader
from surprise.model_selection import train_test_split

# %% [markdown]
# ### Loading the input file ratings.csv.

# %%
ratings=pd.read_csv("C:/Users/Administrator/Desktop/machine learning/Assignment3/Assignment3/MovieRating/ml-latest-small/ratings.csv")

# %% [markdown]
# ### Printing the first few records.

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ### Checking the shape of ratings.

# %%
ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# ### Checking the unique values of ratings.

# %%
ratings["rating"].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: rating, dtype: int64

# %% [markdown]
# ### 1.Creating a  recommender system using ratings.csv file.

# %% [markdown]
# - We are setting the rating scale in the range 0.5 to 5 as 0.5 is the minimum value of rating and 5 is the maximum value of rating.
# - We are considering userId,movieId and rating as the final columns for our dataset.Here we are not considering timestamp column.

# %%
reader=Reader(rating_scale=(0.5,5))
data=Dataset.load_from_df(ratings[["userId","movieId","rating"]],reader)

# %%
data

# %% [markdown]
# ### Splitting our dataset into training and testing sets.

# %%
[trainset,testset]=train_test_split(data,test_size=0.2,shuffle=True)

# %% [markdown]
# - We now create our recommendation model with KNNWithMeans taking 50 as the maximum number of neighbours for aggregation.
# - We are considering cosine distance as the similarity measure.
# - We first fit the model on the trainset and test the model on the testset.
# - We also are calculating the Rmse .

# %%
recom=KNNWithMeans(k=50,sim_options={"name":"cosine","user_based":True})
recom.fit(data.build_full_trainset())
test_pred=recom.test(testset)
RMSE=accuracy.rmse(test_pred)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.7812

# %% [markdown]
# ### 2.Display predicted rating for a particular userID and MovieID combinations (both taken as keyboard input)

# %% [markdown]
# - The user is required to input the user id and the movie id.
# - The below code of lines then displays the the predicted rating for the user with the inputted user id for the given movie id.

# %%
user_id=int(input("Enter the user id :"))
movie_id=int(input("Enter the movie id :"))
r=recom.predict(user_id,movie_id)
print("the predicted rating for the user with user id ",user_id,"for the movie",movie_id,"is :",r.est)
# Out:
# Enter the user id :1
# Enter the movie id :3
# the predicted rating for the user with user id  1 for the movie 3 is : 4.126526481944841

# %% [markdown]
# ### 3.Recommend a user to watch top 10 movies, which has not watched yet (as per his rating predictions). Take userID as a keyboard input. Fix the threshold rating as 2.5

# %% [markdown]
# - The user is required to enter the the user id.
# - A list called all_movies is created which contains the movie ids of all the movies.
# - uid_movies is the list of all the movies which the user has watched.
# - We then use the above two lists, to find the movie ids of the movies which the user has not watched yet.

# %%
uid_input=int(input("Enter the user id : "))
#all_movies contains all the movies
all_movies=ratings.movieId.tolist()
#movies which user has watched
uid_movies=ratings[ratings["userId"]==uid_input]["movieId"].tolist()
#finding movies which user has not watched
not_watched=list(set(all_movies)-set(uid_movies))
# Out:
# Enter the user id : 3

# %% [markdown]
# - The below cell gives us the predicted rating of the inputted user for the movies which he has not watched.
# - We are then storing these rating values in a list rating_value.

# %%
rating_value=[]
for i in not_watched:
    r=recom.predict(uid_input,i)
    print("the predicted rating for the user with user id ",uid_input,"for the movie",i,"is :",r.est)
    rating_value.append(r.est)
# Out:
# the predicted rating for the user with user id  3 for the movie 1 is : 2.7088621793661365
# the predicted rating for the user with user id  3 for the movie 2 is : 2.417923123800971
# the predicted rating for the user with user id  3 for the movie 3 is : 2.1996787344314708
# the predicted rating for the user with user id  3 for the movie 4 is : 1.5244104332995052
# the predicted rating for the user with user id  3 for the movie 5 is : 1.9441406541052129
# the predicted rating for the user with user id  3 for the movie 6 is : 2.933627125258578
# the predicted rating for the user with user id  3 for the movie 7 is : 2.0773016413034773
# the predicted rating for the user with user id  3 for the movie 8 is : 1.612890347476263
# the predicted rating for the user with user id  3 for the movie 9 is : 2.1243353978485198
# the predicted rating for the user with user id  3 for the movie 10 is : 2.280805380982712
# the predicted rating for the user with user id  3 for the movie 11 is : 2.5599296248502617
# the predicted rating for the user with user id  3 for the movie 12 is : 1.5705056102091133
# the predicted rating for the user with user id  3 for the movie 13 is : 2.2886731002405636
# the predicted rating for the user with user id  3 for the movie 14 is : 2.498496041797175
# the predicted rating for the user with user id  3 for the movie 15 is : 2.0798987957513995
# the predicted rating for the user with user id  3 for the movie 16 is : 2.7316242424326287
# the predicted rating for the user with user id  3 for the movie 17 is : 2.6581343491084497
# the predicted rating for the user with user id  3 for the movie 18 is : 2.6657863365781362
# the predicted rating for the user with user id  3 for the movie 19 is : 1.5963596302679932
# the predicted rating for the user with user id  3 for the movie 20 is : 1.6589058809963007
# the predicted rating for the user with user id  3 for the movie 21 is : 2.376666926323282
# the predicted rating for the user with user id  3 for the movie 22 is : 2.285905335771611
# the predicted rating for the user with user id  3 for the movie 23 is : 1.932192827171452
# the predicted rating for the user with user id  3 for the movie 24 is : 2.095777094208503
# the predicted rating for the user with user id  3 for the movie 25 is : 2.335465422312686
# the predicted rating for the user with user id  3 for the movie 26 is : 2.4548198988606353
# the predicted rating for the user with user id  3 for the movie 27 is : 2.1762384374481174
# the predicted rating for the user with user id  3 for the movie 28 is : 3.0263988758544347
# the predicted rating for the user with user id  3 for the movie 29 is : 2.8354735159415756
# the predicted rating for the user with user id  3 for the movie 131098 is : 3.962924462924463
# the predicted rating for the user with user id  3 for the movie 32 is : 2.7202418255761063
# the predicted rating for the user with user id  3 for the movie 131104 is : 3.462924462924463
# the predicted rating for the user with user id  3 for the movie 34 is : 2.566986111813391
# the predicted rating for the user with user id  3 for the movie 30 is : 1.570095757277176
# the predicted rating for the user with user id  3 for the movie 36 is : 2.629811522978319
# the predicted rating for the user with user id  3 for the movie 32799 is : 2.4407636159460977
# the predicted rating for the user with user id  3 for the movie 38 is : 1.463392973307609
# the predicted rating for the user with user id  3 for the movie 39 is : 2.3371738914101057
# the predicted rating for the user with user id  3 for the movie 40 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 41 is : 2.716922397743377
# the predicted rating for the user with user id  3 for the movie 65577 is : 1.5287356321839076
# the predicted rating for the user with user id  3 for the movie 43 is : 2.0410276554035423
# the predicted rating for the user with user id  3 for the movie 44 is : 1.6243969777346927
# the predicted rating for the user with user id  3 for the movie 45 is : 2.286595899680293
# the predicted rating for the user with user id  3 for the movie 46 is : 1.845415466792856
# the predicted rating for the user with user id  3 for the movie 47 is : 2.728667160588647
# the predicted rating for the user with user id  3 for the movie 48 is : 2.105105356588404
# the predicted rating for the user with user id  3 for the movie 65585 is : 2.4864689293990896
# the predicted rating for the user with user id  3 for the movie 50 is : 3.013614020386978
# the predicted rating for the user with user id  3 for the movie 49 is : 1.617038875103391
# the predicted rating for the user with user id  3 for the movie 52 is : 2.2382207988527805
# the predicted rating for the user with user id  3 for the movie 53 is : 3.8114942868956687
# the predicted rating for the user with user id  3 for the movie 54 is : 1.8056053513554624
# the predicted rating for the user with user id  3 for the movie 55 is : 2.7464776406755926
# the predicted rating for the user with user id  3 for the movie 65588 is : 1.4629244629244629
# the predicted rating for the user with user id  3 for the movie 57 is : 1.826699934733935
# the predicted rating for the user with user id  3 for the movie 58 is : 2.7342398296468153
# the predicted rating for the user with user id  3 for the movie 98361 is : 2.175418393981268
# the predicted rating for the user with user id  3 for the movie 60 is : 2.059062444203481
# the predicted rating for the user with user id  3 for the movie 61 is : 2.9407785384968865
# the predicted rating for the user with user id  3 for the movie 62 is : 2.455332738296179
# the predicted rating for the user with user id  3 for the movie 65596 is : 2.7038257227500253
# the predicted rating for the user with user id  3 for the movie 64 is : 0.9495581950865952
# the predicted rating for the user with user id  3 for the movie 65 is : 1.7461468089546899
# the predicted rating for the user with user id  3 for the movie 66 is : 1.270655352918431
# the predicted rating for the user with user id  3 for the movie 131130 is : 3.962924462924463
# the predicted rating for the user with user id  3 for the movie 68 is : 1.6286287626092957
# the predicted rating for the user with user id  3 for the movie 69 is : 2.7791312665096184
# the predicted rating for the user with user id  3 for the movie 70 is : 2.4023645921197847
# the predicted rating for the user with user id  3 for the movie 71 is : 0.6476157876722832
# the predicted rating for the user with user id  3 for the movie 72 is : 2.2879862271488562
# the predicted rating for the user with user id  3 for the movie 73 is : 2.2804073636828033
# the predicted rating for the user with user id  3 for the movie 74 is : 2.4730356806378757
# the predicted rating for the user with user id  3 for the movie 75 is : 1.124160630909928
# the predicted rating for the user with user id  3 for the movie 76 is : 2.391176888243216
# the predicted rating for the user with user id  3 for the movie 77 is : 2.927944095494466
# the predicted rating for the user with user id  3 for the movie 78 is : 2.014046936139917
# the predicted rating for the user with user id  3 for the movie 79 is : 1.5750169759870452
# the predicted rating for the user with user id  3 for the movie 80 is : 2.8511923017705327
# the predicted rating for the user with user id  3 for the movie 81 is : 2.032803448596176
# the predicted rating for the user with user id  3 for the movie 82 is : 2.3685190982149136
# the predicted rating for the user with user id  3 for the movie 83 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 85 is : 2.746824221169871
# the predicted rating for the user with user id  3 for the movie 86 is : 2.8208601834350184
# the predicted rating for the user with user id  3 for the movie 87 is : 1.8667543306375114
# the predicted rating for the user with user id  3 for the movie 88 is : 1.9636397612225975
# the predicted rating for the user with user id  3 for the movie 89 is : 2.3679385852494717
# the predicted rating for the user with user id  3 for the movie 163925 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 92 is : 1.9484491409711624
# the predicted rating for the user with user id  3 for the movie 93 is : 2.1590350805100127
# the predicted rating for the user with user id  3 for the movie 94 is : 3.0171660782286462
# the predicted rating for the user with user id  3 for the movie 95 is : 2.035735535498058
# the predicted rating for the user with user id  3 for the movie 65631 is : 2.679924739651702
# the predicted rating for the user with user id  3 for the movie 97 is : 2.722256708553255
# the predicted rating for the user with user id  3 for the movie 96 is : 2.536941079161193
# the predicted rating for the user with user id  3 for the movie 99 is : 3.7907293005404212
# the predicted rating for the user with user id  3 for the movie 100 is : 1.7503027419877943
# the predicted rating for the user with user id  3 for the movie 101 is : 2.729556051861204
# the predicted rating for the user with user id  3 for the movie 102 is : 0.5
# the predicted rating for the user with user id  3 for the movie 103 is : 1.8965122506111802
# the predicted rating for the user with user id  3 for the movie 104 is : 2.3786737719677897
# the predicted rating for the user with user id  3 for the movie 105 is : 2.2227433872916955
# the predicted rating for the user with user id  3 for the movie 106 is : 2.8803418803418803
# the predicted rating for the user with user id  3 for the movie 107 is : 2.3183891689240914
# the predicted rating for the user with user id  3 for the movie 32875 is : 2.655252274607113
# the predicted rating for the user with user id  3 for the movie 65642 is : 3.3085401546017845
# the predicted rating for the user with user id  3 for the movie 110 is : 2.668303223665144
# the predicted rating for the user with user id  3 for the movie 111 is : 2.6995567041466746
# the predicted rating for the user with user id  3 for the movie 112 is : 2.29773446684454
# the predicted rating for the user with user id  3 for the movie 113 is : 2.253661965434871
# the predicted rating for the user with user id  3 for the movie 108 is : 2.927944095494466
# the predicted rating for the user with user id  3 for the movie 65651 is : 0.5
# the predicted rating for the user with user id  3 for the movie 116 is : 2.2444206136975695
# the predicted rating for the user with user id  3 for the movie 117 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 118 is : 1.968346600235067
# the predicted rating for the user with user id  3 for the movie 119 is : 2.006808176421484
# the predicted rating for the user with user id  3 for the movie 121 is : 2.775541964241761
# the predicted rating for the user with user id  3 for the movie 122 is : 1.6996041733795852
# the predicted rating for the user with user id  3 for the movie 123 is : 2.8091246975224977
# the predicted rating for the user with user id  3 for the movie 32892 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 125 is : 2.8439276024342153
# the predicted rating for the user with user id  3 for the movie 126 is : 1.0811999940018204
# the predicted rating for the user with user id  3 for the movie 128 is : 1.6760290148448043
# the predicted rating for the user with user id  3 for the movie 129 is : 0.5
# the predicted rating for the user with user id  3 for the movie 32898 is : 2.6794042049383395
# the predicted rating for the user with user id  3 for the movie 132 is : 2.0988740219838506
# the predicted rating for the user with user id  3 for the movie 135 is : 1.90977928619585
# the predicted rating for the user with user id  3 for the movie 137 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 32906 is : 2.179924739651702
# the predicted rating for the user with user id  3 for the movie 140 is : 2.14746014026722
# the predicted rating for the user with user id  3 for the movie 141 is : 2.374903993007206
# the predicted rating for the user with user id  3 for the movie 163981 is : 2.24734136830911
# the predicted rating for the user with user id  3 for the movie 144 is : 2.2462760201110443
# the predicted rating for the user with user id  3 for the movie 145 is : 2.202634531346283
# the predicted rating for the user with user id  3 for the movie 146 is : 2.1811916444096324
# the predicted rating for the user with user id  3 for the movie 147 is : 2.6917212723454913
# the predicted rating for the user with user id  3 for the movie 65682 is : 2.391400318252698
# the predicted rating for the user with user id  3 for the movie 148 is : 3.6947209653092004
# the predicted rating for the user with user id  3 for the movie 150 is : 2.553254727137107
# the predicted rating for the user with user id  3 for the movie 151 is : 2.635566518115964
# the predicted rating for the user with user id  3 for the movie 163985 is : 3.011229784494186
# the predicted rating for the user with user id  3 for the movie 153 is : 1.640007724350795
# the predicted rating for the user with user id  3 for the movie 154 is : 2.6854955041917625
# the predicted rating for the user with user id  3 for the movie 155 is : 1.526847626632659
# the predicted rating for the user with user id  3 for the movie 156 is : 1.6724491201173286
# the predicted rating for the user with user id  3 for the movie 157 is : 2.0449521919756077
# the predicted rating for the user with user id  3 for the movie 158 is : 1.783546881440304
# the predicted rating for the user with user id  3 for the movie 159 is : 1.7585301810018743
# the predicted rating for the user with user id  3 for the movie 160 is : 1.8288234843116342
# the predicted rating for the user with user id  3 for the movie 161 is : 2.634208834932105
# the predicted rating for the user with user id  3 for the movie 162 is : 3.1719865189215293
# the predicted rating for the user with user id  3 for the movie 163 is : 2.4118480720187176
# the predicted rating for the user with user id  3 for the movie 164 is : 2.2986050931564463
# the predicted rating for the user with user id  3 for the movie 165 is : 2.395321532368176
# the predicted rating for the user with user id  3 for the movie 131237 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 166 is : 1.9444643543800906
# the predicted rating for the user with user id  3 for the movie 168 is : 1.942433682037171
# the predicted rating for the user with user id  3 for the movie 169 is : 1.5513637585822746
# the predicted rating for the user with user id  3 for the movie 170 is : 2.3141780929686324
# the predicted rating for the user with user id  3 for the movie 171 is : 2.5405873079139614
# the predicted rating for the user with user id  3 for the movie 172 is : 1.8644703494893071
# the predicted rating for the user with user id  3 for the movie 173 is : 1.5869561604086362
# the predicted rating for the user with user id  3 for the movie 174 is : 1.8640470901004036
# the predicted rating for the user with user id  3 for the movie 175 is : 3.0299808005126483
# the predicted rating for the user with user id  3 for the movie 176 is : 3.029058443295377
# the predicted rating for the user with user id  3 for the movie 177 is : 1.9099313195305694
# the predicted rating for the user with user id  3 for the movie 178 is : 0.5
# the predicted rating for the user with user id  3 for the movie 179 is : 0.5
# the predicted rating for the user with user id  3 for the movie 180 is : 2.4848678252550083
# the predicted rating for the user with user id  3 for the movie 181 is : 1.139284563403655
# the predicted rating for the user with user id  3 for the movie 183 is : 2.8914529914529914
# the predicted rating for the user with user id  3 for the movie 184 is : 2.927944095494466
# the predicted rating for the user with user id  3 for the movie 185 is : 2.0327975625579553
# the predicted rating for the user with user id  3 for the movie 186 is : 1.6615811624898766
# the predicted rating for the user with user id  3 for the movie 187 is : 3.8134630206257056
# the predicted rating for the user with user id  3 for the movie 98491 is : 3.1177861328518097
# the predicted rating for the user with user id  3 for the movie 189 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 190 is : 1.4953171322471686
# the predicted rating for the user with user id  3 for the movie 191 is : 1.575093568770572
# the predicted rating for the user with user id  3 for the movie 188 is : 2.7311263474360565
# the predicted rating for the user with user id  3 for the movie 193 is : 1.4225322450550588
# the predicted rating for the user with user id  3 for the movie 194 is : 2.3689419884328506
# the predicted rating for the user with user id  3 for the movie 195 is : 2.297044584776108
# the predicted rating for the user with user id  3 for the movie 196 is : 1.595289616977673
# the predicted rating for the user with user id  3 for the movie 98499 is : 2.2205212017379306
# the predicted rating for the user with user id  3 for the movie 198 is : 2.4334441316806648
# the predicted rating for the user with user id  3 for the movie 199 is : 2.8388042608422546
# the predicted rating for the user with user id  3 for the movie 98503 is : 2.7938473955423104
# the predicted rating for the user with user id  3 for the movie 201 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 65738 is : 3.77025641025641
# the predicted rating for the user with user id  3 for the movie 203 is : 2.361911527036902
# the predicted rating for the user with user id  3 for the movie 204 is : 1.9246064460827683
# the predicted rating for the user with user id  3 for the movie 205 is : 2.211119652748643
# the predicted rating for the user with user id  3 for the movie 65740 is : 3.77025641025641
# the predicted rating for the user with user id  3 for the movie 207 is : 2.2244263779629363
# the predicted rating for the user with user id  3 for the movie 208 is : 1.7743500376473853
# the predicted rating for the user with user id  3 for the movie 209 is : 2.352566866871429
# the predicted rating for the user with user id  3 for the movie 210 is : 2.2256689551552924
# the predicted rating for the user with user id  3 for the movie 211 is : 2.5378440982219312
# the predicted rating for the user with user id  3 for the movie 212 is : 2.3314643147713983
# the predicted rating for the user with user id  3 for the movie 213 is : 3.0943866485837654
# the predicted rating for the user with user id  3 for the movie 214 is : 2.84228035906264
# the predicted rating for the user with user id  3 for the movie 215 is : 2.7549576635283386
# the predicted rating for the user with user id  3 for the movie 216 is : 2.322426233961825
# the predicted rating for the user with user id  3 for the movie 217 is : 1.2131840797203466
# the predicted rating for the user with user id  3 for the movie 218 is : 2.374123006071222
# the predicted rating for the user with user id  3 for the movie 219 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 42 is : 2.038246573729009
# the predicted rating for the user with user id  3 for the movie 220 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 222 is : 2.54915755540253
# the predicted rating for the user with user id  3 for the movie 223 is : 2.683779991446225
# the predicted rating for the user with user id  3 for the movie 224 is : 2.4316273192865716
# the predicted rating for the user with user id  3 for the movie 225 is : 2.2182360200690714
# the predicted rating for the user with user id  3 for the movie 227 is : 1.74940179704659
# the predicted rating for the user with user id  3 for the movie 228 is : 1.030016257001894
# the predicted rating for the user with user id  3 for the movie 229 is : 2.585599799778445
# the predicted rating for the user with user id  3 for the movie 230 is : 2.461527777518108
# the predicted rating for the user with user id  3 for the movie 231 is : 1.7870262912718533
# the predicted rating for the user with user id  3 for the movie 232 is : 2.5124549432372234
# the predicted rating for the user with user id  3 for the movie 233 is : 2.5840805799789752
# the predicted rating for the user with user id  3 for the movie 234 is : 1.8094423247731262
# the predicted rating for the user with user id  3 for the movie 235 is : 2.559853543609551
# the predicted rating for the user with user id  3 for the movie 236 is : 2.4147348071274877
# the predicted rating for the user with user id  3 for the movie 237 is : 2.1095923420766916
# the predicted rating for the user with user id  3 for the movie 33004 is : 2.3329175957835573
# the predicted rating for the user with user id  3 for the movie 239 is : 1.8998052398478205
# the predicted rating for the user with user id  3 for the movie 240 is : 1.671475219988325
# the predicted rating for the user with user id  3 for the movie 238 is : 1.8877492877492874
# the predicted rating for the user with user id  3 for the movie 242 is : 2.6072279529461486
# the predicted rating for the user with user id  3 for the movie 243 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 6560 is : 1.0439404307084068
# the predicted rating for the user with user id  3 for the movie 241 is : 2.6498011792129437
# the predicted rating for the user with user id  3 for the movie 246 is : 3.030663668998474
# the predicted rating for the user with user id  3 for the movie 247 is : 3.0079860517377224
# the predicted rating for the user with user id  3 for the movie 248 is : 2.1216269278875615
# the predicted rating for the user with user id  3 for the movie 249 is : 2.698466422255067
# the predicted rating for the user with user id  3 for the movie 250 is : 1.8528102734370866
# the predicted rating for the user with user id  3 for the movie 251 is : 1.946489532621107
# the predicted rating for the user with user id  3 for the movie 252 is : 2.317905919186739
# the predicted rating for the user with user id  3 for the movie 253 is : 2.327580880900125
# the predicted rating for the user with user id  3 for the movie 254 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 255 is : 0.9446843253529706
# the predicted rating for the user with user id  3 for the movie 256 is : 1.6749650818150577
# the predicted rating for the user with user id  3 for the movie 257 is : 2.2933010752938694
# the predicted rating for the user with user id  3 for the movie 258 is : 1.7663527456744563
# the predicted rating for the user with user id  3 for the movie 259 is : 2.0544626653902114
# the predicted rating for the user with user id  3 for the movie 260 is : 2.8076161465002007
# the predicted rating for the user with user id  3 for the movie 261 is : 2.634756671091315
# the predicted rating for the user with user id  3 for the movie 262 is : 2.844879470875576
# the predicted rating for the user with user id  3 for the movie 263 is : 2.778498332758422
# the predicted rating for the user with user id  3 for the movie 265 is : 2.7696130537356294
# the predicted rating for the user with user id  3 for the movie 266 is : 2.294404389009051
# the predicted rating for the user with user id  3 for the movie 267 is : 1.7843094574880072
# the predicted rating for the user with user id  3 for the movie 65802 is : 1.872358859470276
# the predicted rating for the user with user id  3 for the movie 269 is : 1.7907293005404212
# the predicted rating for the user with user id  3 for the movie 270 is : 2.0884494496256054
# the predicted rating for the user with user id  3 for the movie 271 is : 2.200088712253747
# the predicted rating for the user with user id  3 for the movie 272 is : 2.6047137390742856
# the predicted rating for the user with user id  3 for the movie 273 is : 1.7989335904826411
# the predicted rating for the user with user id  3 for the movie 274 is : 2.274885630486955
# the predicted rating for the user with user id  3 for the movie 275 is : 1.1436789528051532
# the predicted rating for the user with user id  3 for the movie 276 is : 2.2725889608194048
# the predicted rating for the user with user id  3 for the movie 277 is : 2.21545643314237
# the predicted rating for the user with user id  3 for the movie 65810 is : 1.7394347207922731
# the predicted rating for the user with user id  3 for the movie 279 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 280 is : 2.8811248697238234
# the predicted rating for the user with user id  3 for the movie 281 is : 2.646857678469197
# the predicted rating for the user with user id  3 for the movie 282 is : 2.2155823951567015
# the predicted rating for the user with user id  3 for the movie 98585 is : 2.406525645676305
# the predicted rating for the user with user id  3 for the movie 283 is : 2.419731586974486
# the predicted rating for the user with user id  3 for the movie 278 is : 0.8701363608658017
# the predicted rating for the user with user id  3 for the movie 284 is : 3.011328470380194
# the predicted rating for the user with user id  3 for the movie 287 is : 1.7464776406755926
# the predicted rating for the user with user id  3 for the movie 288 is : 2.288676066750863
# the predicted rating for the user with user id  3 for the movie 289 is : 2.428650266017889
# the predicted rating for the user with user id  3 for the movie 290 is : 2.727265761300575
# the predicted rating for the user with user id  3 for the movie 291 is : 1.6589983842158316
# the predicted rating for the user with user id  3 for the movie 292 is : 2.135254488794102
# the predicted rating for the user with user id  3 for the movie 293 is : 2.73005586763972
# the predicted rating for the user with user id  3 for the movie 294 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 295 is : 2.8285005653426705
# the predicted rating for the user with user id  3 for the movie 296 is : 2.72445302727765
# the predicted rating for the user with user id  3 for the movie 298 is : 0.5
# the predicted rating for the user with user id  3 for the movie 299 is : 2.9028770902684813
# the predicted rating for the user with user id  3 for the movie 300 is : 2.43331739336613
# the predicted rating for the user with user id  3 for the movie 98604 is : 2.8195539455927263
# the predicted rating for the user with user id  3 for the movie 302 is : 1.935047320000285
# the predicted rating for the user with user id  3 for the movie 303 is : 1.9543884411661583
# the predicted rating for the user with user id  3 for the movie 304 is : 2.8108797998970236
# the predicted rating for the user with user id  3 for the movie 305 is : 2.101387948824785
# the predicted rating for the user with user id  3 for the movie 306 is : 3.027282499457449
# the predicted rating for the user with user id  3 for the movie 307 is : 2.76381380203299
# the predicted rating for the user with user id  3 for the movie 308 is : 2.9351158978208347
# the predicted rating for the user with user id  3 for the movie 98607 is : 3.0761752136752136
# the predicted rating for the user with user id  3 for the movie 310 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 311 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 312 is : 0.6377785903834687
# the predicted rating for the user with user id  3 for the movie 313 is : 1.8593070076088583
# the predicted rating for the user with user id  3 for the movie 314 is : 2.688950199312014
# the predicted rating for the user with user id  3 for the movie 315 is : 2.047678573248043
# the predicted rating for the user with user id  3 for the movie 316 is : 2.351304802654789
# the predicted rating for the user with user id  3 for the movie 317 is : 2.0988826476005142
# the predicted rating for the user with user id  3 for the movie 318 is : 2.968142186578627
# the predicted rating for the user with user id  3 for the movie 319 is : 2.5379870845718115
# the predicted rating for the user with user id  3 for the movie 63 is : 1.659011450563277
# the predicted rating for the user with user id  3 for the movie 321 is : 2.760229922384032
# the predicted rating for the user with user id  3 for the movie 322 is : 2.4661801722072347
# the predicted rating for the user with user id  3 for the movie 33090 is : 3.4534188368206387
# the predicted rating for the user with user id  3 for the movie 324 is : 2.7464776406755926
# the predicted rating for the user with user id  3 for the movie 325 is : 1.5262778088538118
# the predicted rating for the user with user id  3 for the movie 326 is : 2.7124478571660697
# the predicted rating for the user with user id  3 for the movie 327 is : 1.9443742348485251
# the predicted rating for the user with user id  3 for the movie 328 is : 2.2168469986214228
# the predicted rating for the user with user id  3 for the movie 329 is : 2.2427869056771037
# the predicted rating for the user with user id  3 for the movie 330 is : 2.3045498376246556
# the predicted rating for the user with user id  3 for the movie 331 is : 1.8422803590626406
# the predicted rating for the user with user id  3 for the movie 332 is : 1.985610539954154
# the predicted rating for the user with user id  3 for the movie 333 is : 2.7240111405511342
# the predicted rating for the user with user id  3 for the movie 334 is : 3.433754062837646
# the predicted rating for the user with user id  3 for the movie 335 is : 2.441287266811974
# the predicted rating for the user with user id  3 for the movie 336 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 337 is : 2.713855164748431
# the predicted rating for the user with user id  3 for the movie 338 is : 1.8193018642341252
# the predicted rating for the user with user id  3 for the movie 339 is : 2.297604911418642
# the predicted rating for the user with user id  3 for the movie 340 is : 2.6516732195923085
# the predicted rating for the user with user id  3 for the movie 164179 is : 2.722435991860311
# the predicted rating for the user with user id  3 for the movie 342 is : 2.189049368753407
# the predicted rating for the user with user id  3 for the movie 343 is : 1.9018325203729494
# the predicted rating for the user with user id  3 for the movie 344 is : 1.789143354065442
# the predicted rating for the user with user id  3 for the movie 345 is : 2.4522798131226127
# the predicted rating for the user with user id  3 for the movie 346 is : 2.5861857247358504
# the predicted rating for the user with user id  3 for the movie 347 is : 2.4262281648480575
# the predicted rating for the user with user id  3 for the movie 348 is : 2.4541407943933695
# the predicted rating for the user with user id  3 for the movie 349 is : 2.5846686314478005
# the predicted rating for the user with user id  3 for the movie 350 is : 2.373286235048068
# the predicted rating for the user with user id  3 for the movie 351 is : 2.212674216733569
# the predicted rating for the user with user id  3 for the movie 352 is : 1.5869459783752484
# the predicted rating for the user with user id  3 for the movie 353 is : 2.6547879498728384
# the predicted rating for the user with user id  3 for the movie 354 is : 2.469835142140341
# the predicted rating for the user with user id  3 for the movie 355 is : 1.5074827668672426
# the predicted rating for the user with user id  3 for the movie 356 is : 2.7785769004525225
# the predicted rating for the user with user id  3 for the movie 357 is : 2.452874148400415
# the predicted rating for the user with user id  3 for the movie 358 is : 1.4693915719360235
# the predicted rating for the user with user id  3 for the movie 359 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 360 is : 1.8983271652005036
# the predicted rating for the user with user id  3 for the movie 361 is : 2.139934957340266
# the predicted rating for the user with user id  3 for the movie 362 is : 2.6079711711178017
# the predicted rating for the user with user id  3 for the movie 33124 is : 1.8195539455927263
# the predicted rating for the user with user id  3 for the movie 364 is : 2.6895894215962586
# the predicted rating for the user with user id  3 for the movie 365 is : 2.0405556843883836
# the predicted rating for the user with user id  3 for the movie 366 is : 1.9547091202139188
# the predicted rating for the user with user id  3 for the movie 367 is : 2.042177451839497
# the predicted rating for the user with user id  3 for the movie 368 is : 2.543762393659044
# the predicted rating for the user with user id  3 for the movie 369 is : 2.84228035906264
# the predicted rating for the user with user id  3 for the movie 370 is : 2.003598224464394
# the predicted rating for the user with user id  3 for the movie 371 is : 2.4144045081967427
# the predicted rating for the user with user id  3 for the movie 372 is : 1.8480785569432405
# the predicted rating for the user with user id  3 for the movie 131439 is : 1.9629244629244629
# the predicted rating for the user with user id  3 for the movie 374 is : 1.2596344964549997
# the predicted rating for the user with user id  3 for the movie 373 is : 2.4691110710214064
# the predicted rating for the user with user id  3 for the movie 376 is : 2.1299597679067794
# the predicted rating for the user with user id  3 for the movie 377 is : 2.475062883318646
# the predicted rating for the user with user id  3 for the movie 378 is : 2.0767647015787665
# the predicted rating for the user with user id  3 for the movie 33145 is : 1.9630537939640884
# the predicted rating for the user with user id  3 for the movie 380 is : 2.19717730297115
# the predicted rating for the user with user id  3 for the movie 381 is : 2.3998703197480786
# the predicted rating for the user with user id  3 for the movie 382 is : 1.9812735860386717
# the predicted rating for the user with user id  3 for the movie 383 is : 2.0422549459895145
# the predicted rating for the user with user id  3 for the movie 379 is : 1.6240991191334633
# the predicted rating for the user with user id  3 for the movie 385 is : 2.6474358974358974
# the predicted rating for the user with user id  3 for the movie 33154 is : 2.790586969369641
# the predicted rating for the user with user id  3 for the movie 387 is : 1.6918645783359954
# the predicted rating for the user with user id  3 for the movie 164226 is : 3.462924462924463
# the predicted rating for the user with user id  3 for the movie 384 is : 2.0665758940516796
# the predicted rating for the user with user id  3 for the movie 390 is : 2.5185248543648133
# the predicted rating for the user with user id  3 for the movie 391 is : 3.8823260073260073
# the predicted rating for the user with user id  3 for the movie 33158 is : 0.9344831575673123
# the predicted rating for the user with user id  3 for the movie 393 is : 1.641007624521674
# the predicted rating for the user with user id  3 for the movie 33162 is : 2.450583691400484
# the predicted rating for the user with user id  3 for the movie 388 is : 1.9119257413894297
# the predicted rating for the user with user id  3 for the movie 33164 is : 1.3063768653728287
# the predicted rating for the user with user id  3 for the movie 389 is : 3.201411861591502
# the predicted rating for the user with user id  3 for the movie 33166 is : 2.791112761750873
# the predicted rating for the user with user id  3 for the movie 98697 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 33171 is : 1.3987366596063708
# the predicted rating for the user with user id  3 for the movie 405 is : 1.6630024629094273
# the predicted rating for the user with user id  3 for the movie 406 is : 1.7464776406755926
# the predicted rating for the user with user id  3 for the movie 407 is : 2.336220619410111
# the predicted rating for the user with user id  3 for the movie 408 is : 1.9787636569598783
# the predicted rating for the user with user id  3 for the movie 409 is : 1.77025641025641
# the predicted rating for the user with user id  3 for the movie 410 is : 2.1945225399564383
# the predicted rating for the user with user id  3 for the movie 131480 is : 1.5885261912622424
# the predicted rating for the user with user id  3 for the movie 412 is : 2.461369224020308
# the predicted rating for the user with user id  3 for the movie 413 is : 1.824081959527545
# the predicted rating for the user with user id  3 for the movie 414 is : 1.7045363262893902
# the predicted rating for the user with user id  3 for the movie 415 is : 1.7770987405270358
# the predicted rating for the user with user id  3 for the movie 416 is : 1.6101759678185539
# the predicted rating for the user with user id  3 for the movie 417 is : 2.6342902252268066
# the predicted rating for the user with user id  3 for the movie 418 is : 2.1001990496769465
# the predicted rating for the user with user id  3 for the movie 419 is : 1.5483901346747544
# the predicted rating for the user with user id  3 for the movie 420 is : 1.709690205489856
# the predicted rating for the user with user id  3 for the movie 421 is : 2.1007886377127574
# the predicted rating for the user with user id  3 for the movie 422 is : 2.4142848895681093
# the predicted rating for the user with user id  3 for the movie 423 is : 1.9618813157285029
# the predicted rating for the user with user id  3 for the movie 424 is : 0.8252671265345353
# the predicted rating for the user with user id  3 for the movie 425 is : 2.656837068794566
# the predicted rating for the user with user id  3 for the movie 426 is : 2.485463567917934
# the predicted rating for the user with user id  3 for the movie 427 is : 1.3217498677281931
# the predicted rating for the user with user id  3 for the movie 428 is : 2.7223469566794813
# the predicted rating for the user with user id  3 for the movie 429 is : 1.505027207783698
# the predicted rating for the user with user id  3 for the movie 430 is : 1.801721743960011
# the predicted rating for the user with user id  3 for the movie 431 is : 2.6112773358723596
# the predicted rating for the user with user id  3 for the movie 432 is : 1.59990413227943
# the predicted rating for the user with user id  3 for the movie 433 is : 1.975194631555498
# the predicted rating for the user with user id  3 for the movie 434 is : 1.953692460709829
# the predicted rating for the user with user id  3 for the movie 435 is : 1.3630631097729462
# the predicted rating for the user with user id  3 for the movie 436 is : 1.6737216854663268
# the predicted rating for the user with user id  3 for the movie 437 is : 1.4363844782750637
# the predicted rating for the user with user id  3 for the movie 33201 is : 3.0761752136752136
# the predicted rating for the user with user id  3 for the movie 438 is : 2.1615476430433507
# the predicted rating for the user with user id  3 for the movie 440 is : 2.4501375202225604
# the predicted rating for the user with user id  3 for the movie 441 is : 2.936040557104525
# the predicted rating for the user with user id  3 for the movie 442 is : 2.116726105982195
# the predicted rating for the user with user id  3 for the movie 164280 is : 3.155252274607113
# the predicted rating for the user with user id  3 for the movie 444 is : 1.3222854279638678
# the predicted rating for the user with user id  3 for the movie 445 is : 2.0988702265900825
# the predicted rating for the user with user id  3 for the movie 65982 is : 2.6807932823837346
# the predicted rating for the user with user id  3 for the movie 446 is : 2.2361246582878325
# the predicted rating for the user with user id  3 for the movie 448 is : 2.5115042743313256
# the predicted rating for the user with user id  3 for the movie 449 is : 0.5
# the predicted rating for the user with user id  3 for the movie 450 is : 2.1096138036317384
# the predicted rating for the user with user id  3 for the movie 451 is : 2.762779156327543
# the predicted rating for the user with user id  3 for the movie 452 is : 1.9563549787997982
# the predicted rating for the user with user id  3 for the movie 453 is : 1.9800144554944032
# the predicted rating for the user with user id  3 for the movie 454 is : 2.3677595823767357
# the predicted rating for the user with user id  3 for the movie 455 is : 1.5735665460830663
# the predicted rating for the user with user id  3 for the movie 456 is : 2.4940450961466953
# the predicted rating for the user with user id  3 for the movie 457 is : 2.9236282862185425
# the predicted rating for the user with user id  3 for the movie 458 is : 1.928779828969961
# the predicted rating for the user with user id  3 for the movie 459 is : 1.483663204057623
# the predicted rating for the user with user id  3 for the movie 460 is : 2.0196710513053064
# the predicted rating for the user with user id  3 for the movie 461 is : 1.1013542765775435
# the predicted rating for the user with user id  3 for the movie 464 is : 2.1284917861138375
# the predicted rating for the user with user id  3 for the movie 466 is : 1.8738273045657547
# the predicted rating for the user with user id  3 for the movie 467 is : 3.5681288408561134
# the predicted rating for the user with user id  3 for the movie 468 is : 2.366092819305543
# the predicted rating for the user with user id  3 for the movie 469 is : 2.12226716655354
# the predicted rating for the user with user id  3 for the movie 470 is : 0.8249134542040717
# the predicted rating for the user with user id  3 for the movie 471 is : 2.4309665782304406
# the predicted rating for the user with user id  3 for the movie 472 is : 1.9544427919879608
# the predicted rating for the user with user id  3 for the movie 473 is : 1.2924417574172413
# the predicted rating for the user with user id  3 for the movie 474 is : 2.602901509926395
# the predicted rating for the user with user id  3 for the movie 475 is : 3.071489983854468
# the predicted rating for the user with user id  3 for the movie 476 is : 0.5
# the predicted rating for the user with user id  3 for the movie 477 is : 2.368260000565716
# the predicted rating for the user with user id  3 for the movie 478 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 479 is : 1.2211688350043937
# the predicted rating for the user with user id  3 for the movie 480 is : 2.3579717423371775
# the predicted rating for the user with user id  3 for the movie 481 is : 2.198212161704198
# the predicted rating for the user with user id  3 for the movie 482 is : 2.7431536926869704
# the predicted rating for the user with user id  3 for the movie 484 is : 0.5
# the predicted rating for the user with user id  3 for the movie 485 is : 1.9592315851815245
# the predicted rating for the user with user id  3 for the movie 486 is : 2.1519475241844352
# the predicted rating for the user with user id  3 for the movie 487 is : 2.0070295796406725
# the predicted rating for the user with user id  3 for the movie 488 is : 2.036941079161193
# the predicted rating for the user with user id  3 for the movie 489 is : 1.989686094705327
# the predicted rating for the user with user id  3 for the movie 490 is : 1.9956962324186707
# the predicted rating for the user with user id  3 for the movie 491 is : 2.3698339727630975
# the predicted rating for the user with user id  3 for the movie 492 is : 2.579627633195976
# the predicted rating for the user with user id  3 for the movie 493 is : 2.6070307093718577
# the predicted rating for the user with user id  3 for the movie 494 is : 2.548702873454742
# the predicted rating for the user with user id  3 for the movie 98799 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 496 is : 3.6947209653092004
# the predicted rating for the user with user id  3 for the movie 497 is : 2.723329023465807
# the predicted rating for the user with user id  3 for the movie 495 is : 3.927944095494466
# the predicted rating for the user with user id  3 for the movie 499 is : 1.8949143406288287
# the predicted rating for the user with user id  3 for the movie 500 is : 2.336112243414523
# the predicted rating for the user with user id  3 for the movie 501 is : 2.414421348407303
# the predicted rating for the user with user id  3 for the movie 502 is : 1.4357347951254253
# the predicted rating for the user with user id  3 for the movie 504 is : 2.362969324214187
# the predicted rating for the user with user id  3 for the movie 505 is : 1.5647608437477514
# the predicted rating for the user with user id  3 for the movie 98809 is : 2.6109451248443856
# the predicted rating for the user with user id  3 for the movie 507 is : 2.34774825590675
# the predicted rating for the user with user id  3 for the movie 508 is : 2.643877480912169
# the predicted rating for the user with user id  3 for the movie 509 is : 2.337348096061911
# the predicted rating for the user with user id  3 for the movie 510 is : 1.9422668626490283
# the predicted rating for the user with user id  3 for the movie 511 is : 1.0439404307084068
# the predicted rating for the user with user id  3 for the movie 512 is : 2.0572189362404774
# the predicted rating for the user with user id  3 for the movie 513 is : 2.647954042504755
# the predicted rating for the user with user id  3 for the movie 514 is : 2.416726818355304
# the predicted rating for the user with user id  3 for the movie 515 is : 2.395619726769606
# the predicted rating for the user with user id  3 for the movie 516 is : 2.282272178606571
# the predicted rating for the user with user id  3 for the movie 517 is : 2.387237761549247
# the predicted rating for the user with user id  3 for the movie 518 is : 1.9504946079914647
# the predicted rating for the user with user id  3 for the movie 519 is : 1.461532746050426
# the predicted rating for the user with user id  3 for the movie 520 is : 2.0323358863591254
# the predicted rating for the user with user id  3 for the movie 521 is : 2.294557728157071
# the predicted rating for the user with user id  3 for the movie 522 is : 2.1409467534501085
# the predicted rating for the user with user id  3 for the movie 523 is : 2.060244838248757
# the predicted rating for the user with user id  3 for the movie 524 is : 2.4623096560172586
# the predicted rating for the user with user id  3 for the movie 33294 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 528 is : 1.9148860868235422
# the predicted rating for the user with user id  3 for the movie 529 is : 2.6781918915338134
# the predicted rating for the user with user id  3 for the movie 164367 is : 3.6310897435897433
# the predicted rating for the user with user id  3 for the movie 531 is : 2.41615880192267
# the predicted rating for the user with user id  3 for the movie 532 is : 1.7956084414862312
# the predicted rating for the user with user id  3 for the movie 533 is : 2.0841011338833817
# the predicted rating for the user with user id  3 for the movie 534 is : 2.488067015033519
# the predicted rating for the user with user id  3 for the movie 535 is : 2.189796745839301
# the predicted rating for the user with user id  3 for the movie 536 is : 2.360813243196239
# the predicted rating for the user with user id  3 for the movie 537 is : 2.2497863129385527
# the predicted rating for the user with user id  3 for the movie 538 is : 2.6218045384381687
# the predicted rating for the user with user id  3 for the movie 539 is : 2.390385353221591
# the predicted rating for the user with user id  3 for the movie 540 is : 1.9249315875800166
# the predicted rating for the user with user id  3 for the movie 541 is : 2.8672547798266006
# the predicted rating for the user with user id  3 for the movie 542 is : 1.9290446945929636
# the predicted rating for the user with user id  3 for the movie 543 is : 2.3320479600472668
# the predicted rating for the user with user id  3 for the movie 544 is : 1.579955270709347
# the predicted rating for the user with user id  3 for the movie 131610 is : 3.962924462924463
# the predicted rating for the user with user id  3 for the movie 546 is : 1.2102413770851657
# the predicted rating for the user with user id  3 for the movie 547 is : 2.4947511970310963
# the predicted rating for the user with user id  3 for the movie 548 is : 2.0546686032025363
# the predicted rating for the user with user id  3 for the movie 33312 is : 2.5444245676803816
# the predicted rating for the user with user id  3 for the movie 550 is : 2.273836891024845
# the predicted rating for the user with user id  3 for the movie 551 is : 2.5111584256348376
# ...
# the predicted rating for the user with user id  3 for the movie 31694 is : 2.345341668808113
# the predicted rating for the user with user id  3 for the movie 97230 is : 2.7938473955423104
# the predicted rating for the user with user id  3 for the movie 31696 is : 2.19972185818261
# the predicted rating for the user with user id  3 for the movie 31698 is : 0.5
# the predicted rating for the user with user id  3 for the movie 31700 is : 2.23561125291052
# the predicted rating for the user with user id  3 for the movie 31702 is : 2.309009218374777
# the predicted rating for the user with user id  3 for the movie 64497 is : 1.6517873917761665
# the predicted rating for the user with user id  3 for the movie 64499 is : 3.511229784494186
# the predicted rating for the user with user id  3 for the movie 64501 is : 3.511229784494186
# the predicted rating for the user with user id  3 for the movie 31737 is : 2.677377474845829
# the predicted rating for the user with user id  3 for the movie 130050 is : 1.74734136830911
# the predicted rating for the user with user id  3 for the movie 130052 is : 2.24734136830911
# the predicted rating for the user with user id  3 for the movie 97285 is : 2.24734136830911
# the predicted rating for the user with user id  3 for the movie 162828 is : 2.0885261912622424
# the predicted rating for the user with user id  3 for the movie 97304 is : 2.6823386343130804
# the predicted rating for the user with user id  3 for the movie 130073 is : 3.2196233459616757
# the predicted rating for the user with user id  3 for the movie 97306 is : 2.2831392630849336
# the predicted rating for the user with user id  3 for the movie 130083 is : 1.5885261912622424
# the predicted rating for the user with user id  3 for the movie 130087 is : 2.0961141541636894
# the predicted rating for the user with user id  3 for the movie 97328 is : 2.5885261912622424
# the predicted rating for the user with user id  3 for the movie 31804 is : 2.047022289178669
# the predicted rating for the user with user id  3 for the movie 64575 is : 2.5305033947502285
# the predicted rating for the user with user id  3 for the movie 64614 is : 2.7119881248125255
# the predicted rating for the user with user id  3 for the movie 31851 is : 1.9629244629244629
# the predicted rating for the user with user id  3 for the movie 64620 is : 2.6802400653469007
# the predicted rating for the user with user id  3 for the movie 64622 is : 2.4656729748873536
# the predicted rating for the user with user id  3 for the movie 31867 is : 2.1853173894937235
# the predicted rating for the user with user id  3 for the movie 31878 is : 2.6025839788390255
# the predicted rating for the user with user id  3 for the movie 162968 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 31903 is : 3.036941079161193
# the predicted rating for the user with user id  3 for the movie 31909 is : 3.2000133348573168
# the predicted rating for the user with user id  3 for the movie 162982 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 31921 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 31923 is : 2.917918730143073
# the predicted rating for the user with user id  3 for the movie 31925 is : 2.962924462924463
# the predicted rating for the user with user id  3 for the movie 64695 is : 2.6310897435897433
# the predicted rating for the user with user id  3 for the movie 97470 is : 0.5163784886316403
# the predicted rating for the user with user id  3 for the movie 64716 is : 2.801553114031406
# the predicted rating for the user with user id  3 for the movie 31952 is : 2.179924739651702
# the predicted rating for the user with user id  3 for the movie 31973 is : 2.278498332758422
# the predicted rating for the user with user id  3 for the movie 163056 is : 2.76266262473159
# the predicted rating for the user with user id  3 for the movie 163072 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 32009 is : 1.7686780806288502
# the predicted rating for the user with user id  3 for the movie 32011 is : 1.3307741672329791
# the predicted rating for the user with user id  3 for the movie 32017 is : 1.7828504736668394
# the predicted rating for the user with user id  3 for the movie 32019 is : 1.6704009202698669
# the predicted rating for the user with user id  3 for the movie 32022 is : 2.49377108418014
# the predicted rating for the user with user id  3 for the movie 32029 is : 2.0903403359974866
# the predicted rating for the user with user id  3 for the movie 32031 is : 2.34865715898328
# the predicted rating for the user with user id  3 for the movie 163112 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 32058 is : 1.7938473955423104
# the predicted rating for the user with user id  3 for the movie 32060 is : 1.9629244629244629
# the predicted rating for the user with user id  3 for the movie 163134 is : 2.697585839440559
# the predicted rating for the user with user id  3 for the movie 64839 is : 2.688945412393177
# the predicted rating for the user with user id  3 for the movie 97643 is : 1.754955645905107
# the predicted rating for the user with user id  3 for the movie 32116 is : 1.5439404307084068
# the predicted rating for the user with user id  3 for the movie 97665 is : 1.3170787545787546
# the predicted rating for the user with user id  3 for the movie 32139 is : 2.5236836954394204
# the predicted rating for the user with user id  3 for the movie 130444 is : 2.3561872909698995
# the predicted rating for the user with user id  3 for the movie 130450 is : 1.49453366521859
# the predicted rating for the user with user id  3 for the movie 130452 is : 2.962924462924463
# the predicted rating for the user with user id  3 for the movie 97701 is : 1.74734136830911
# the predicted rating for the user with user id  3 for the movie 130482 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 32179 is : 2.752970606629143
# the predicted rating for the user with user id  3 for the movie 130490 is : 1.7068569095863801
# the predicted rating for the user with user id  3 for the movie 64957 is : 2.6155111717293793
# the predicted rating for the user with user id  3 for the movie 130498 is : 2.368211846377785
# the predicted rating for the user with user id  3 for the movie 64969 is : 2.534392845129842
# the predicted rating for the user with user id  3 for the movie 97742 is : 1.0885261912622424
# the predicted rating for the user with user id  3 for the movie 32213 is : 1.9142267892497915
# the predicted rating for the user with user id  3 for the movie 130518 is : 2.9534188368206387
# the predicted rating for the user with user id  3 for the movie 64983 is : 2.290099138065204
# the predicted rating for the user with user id  3 for the movie 97752 is : 2.5069812524705415
# the predicted rating for the user with user id  3 for the movie 130520 is : 1.9976677463648678
# the predicted rating for the user with user id  3 for the movie 97757 is : 2.8366464995678475
# the predicted rating for the user with user id  3 for the movie 64993 is : 3.0170139985400377
# the predicted rating for the user with user id  3 for the movie 64997 is : 2.3550724212132854
# the predicted rating for the user with user id  3 for the movie 32234 is : 2.778498332758422
# the predicted rating for the user with user id  3 for the movie 32243 is : 2.462924462924463
# the predicted rating for the user with user id  3 for the movie 97785 is : 1.7626626247315902
# the predicted rating for the user with user id  3 for the movie 65037 is : 2.179924739651702
# the predicted rating for the user with user id  3 for the movie 130576 is : 1.3959443319289577
# the predicted rating for the user with user id  3 for the movie 130578 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 32289 is : 2.219725635341719
# the predicted rating for the user with user id  3 for the movie 32291 is : 2.479169207890069
# the predicted rating for the user with user id  3 for the movie 32294 is : 2.6607778186725555
# the predicted rating for the user with user id  3 for the movie 32296 is : 1.4023150319099311
# the predicted rating for the user with user id  3 for the movie 32298 is : 1.570003925131203
# the predicted rating for the user with user id  3 for the movie 97836 is : 1.9157007709949743
# the predicted rating for the user with user id  3 for the movie 32300 is : 2.0813009235895357
# the predicted rating for the user with user id  3 for the movie 32302 is : 3.301721743960011
# the predicted rating for the user with user id  3 for the movie 163386 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 32314 is : 2.677377474845829
# the predicted rating for the user with user id  3 for the movie 65088 is : 2.481410915594363
# the predicted rating for the user with user id  3 for the movie 97858 is : 1.5885261912622424
# the predicted rating for the user with user id  3 for the movie 97860 is : 2.0979617585486805
# the predicted rating for the user with user id  3 for the movie 130634 is : 1.9206013659229781
# the predicted rating for the user with user id  3 for the movie 97866 is : 3.5165397330513333
# the predicted rating for the user with user id  3 for the movie 97870 is : 3.5885261912622424
# the predicted rating for the user with user id  3 for the movie 65126 is : 2.1538958381006488
# the predicted rating for the user with user id  3 for the movie 65130 is : 2.6607480130293504
# the predicted rating for the user with user id  3 for the movie 65133 is : 2.6867064000307375
# the predicted rating for the user with user id  3 for the movie 65135 is : 2.5885261912622424
# the predicted rating for the user with user id  3 for the movie 97904 is : 2.679924739651702
# the predicted rating for the user with user id  3 for the movie 97913 is : 2.711044655561896
# the predicted rating for the user with user id  3 for the movie 130686 is : 1.9273063706053395
# the predicted rating for the user with user id  3 for the movie 97921 is : 2.6763192576822816
# the predicted rating for the user with user id  3 for the movie 97923 is : 2.5215721126439634
# the predicted rating for the user with user id  3 for the movie 32387 is : 3.4723129452992767
# the predicted rating for the user with user id  3 for the movie 32392 is : 1.6773774748458292
# the predicted rating for the user with user id  3 for the movie 97936 is : 2.5885261912622424
# the predicted rating for the user with user id  3 for the movie 97938 is : 2.5574470095748243
# the predicted rating for the user with user id  3 for the movie 97950 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 65188 is : 3.308116909194128
# the predicted rating for the user with user id  3 for the movie 65193 is : 2.2196233459616757
# the predicted rating for the user with user id  3 for the movie 32440 is : 1.7938473955423104
# the predicted rating for the user with user id  3 for the movie 32442 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 65216 is : 2.660237050698133
# the predicted rating for the user with user id  3 for the movie 97988 is : 1.2473413683091101
# the predicted rating for the user with user id  3 for the movie 163527 is : 2.962924462924463
# the predicted rating for the user with user id  3 for the movie 32456 is : 3.29110206045556
# the predicted rating for the user with user id  3 for the movie 65225 is : 3.179924739651702
# the predicted rating for the user with user id  3 for the movie 32460 is : 2.7933249380656484
# the predicted rating for the user with user id  3 for the movie 65230 is : 2.265601350246076
# the predicted rating for the user with user id  3 for the movie 32469 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 65261 is : 2.9127041191451637
# the predicted rating for the user with user id  3 for the movie 32511 is : 3.179924739651702
# the predicted rating for the user with user id  3 for the movie 32515 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 98061 is : 2.24734136830911
# the predicted rating for the user with user id  3 for the movie 130840 is : 3.24734136830911
# the predicted rating for the user with user id  3 for the movie 130842 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 98083 is : 3.1740528916861166
# the predicted rating for the user with user id  3 for the movie 32554 is : 2.944414465371386
# the predicted rating for the user with user id  3 for the movie 163639 is : 2.9407636159460977
# the predicted rating for the user with user id  3 for the movie 163645 is : 2.789121330277575
# the predicted rating for the user with user id  3 for the movie 163653 is : 1.8938974358974359
# the predicted rating for the user with user id  3 for the movie 65350 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 32582 is : 3.820952907096376
# the predicted rating for the user with user id  3 for the movie 32584 is : 2.128480169708507
# the predicted rating for the user with user id  3 for the movie 98122 is : 2.2808915414178963
# the predicted rating for the user with user id  3 for the movie 32587 is : 2.6570964661569314
# the predicted rating for the user with user id  3 for the movie 98124 is : 2.948416171013031
# the predicted rating for the user with user id  3 for the movie 32589 is : 1.1853173894937235
# the predicted rating for the user with user id  3 for the movie 65359 is : 2.225490196078431
# the predicted rating for the user with user id  3 for the movie 32596 is : 1.9757023851031899
# the predicted rating for the user with user id  3 for the movie 32598 is : 2.0874798344937777
# the predicted rating for the user with user id  3 for the movie 32600 is : 2.278498332758422
# the predicted rating for the user with user id  3 for the movie 98154 is : 3.359246131285888
# the predicted rating for the user with user id  3 for the movie 32620 is : 2.278498332758422
# the predicted rating for the user with user id  3 for the movie 98160 is : 1.0885261912622424
# the predicted rating for the user with user id  3 for the movie 32632 is : 1.809009218374777
# the predicted rating for the user with user id  3 for the movie 98175 is : 1.0885261912622424
# the predicted rating for the user with user id  3 for the movie 32649 is : 2.778498332758422
# the predicted rating for the user with user id  3 for the movie 32657 is : 3.0707078054319488
# the predicted rating for the user with user id  3 for the movie 32659 is : 2.155252274607113
# the predicted rating for the user with user id  3 for the movie 130970 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 98203 is : 0.5
# the predicted rating for the user with user id  3 for the movie 32666 is : 0.5
# the predicted rating for the user with user id  3 for the movie 130976 is : 2.8195539455927263
# the predicted rating for the user with user id  3 for the movie 130978 is : 3.3195539455927263
# the predicted rating for the user with user id  3 for the movie 98230 is : 3.0885261912622424
# the predicted rating for the user with user id  3 for the movie 98239 is : 0.9766888482189919
# the predicted rating for the user with user id  3 for the movie 98243 is : 2.5581097452054684
# the predicted rating for the user with user id  3 for the movie 131013 is : 2.238056993355065
# the predicted rating for the user with user id  3 for the movie 131023 is : 2.4358974358974357
# the predicted rating for the user with user id  3 for the movie 32728 is : 2.778498332758422
# the predicted rating for the user with user id  3 for the movie 163809 is : 2.2938473955423104
# the predicted rating for the user with user id  3 for the movie 98279 is : 3.38973948178223
# the predicted rating for the user with user id  3 for the movie 32743 is : 1.7626626247315902
# the predicted rating for the user with user id  3 for the movie 65514 is : 2.7420698258793084
# the predicted rating for the user with user id  3 for the movie 98296 is : 1.0885261912622424

# %% [markdown]
# - We now create a dataframe which contains the movie ids for the movies which the user has not watched and also their predicted ratings.

# %%
movieid_rating=pd.DataFrame({"movie_id":not_watched,"rating":rating_value})

# %% [markdown]
# - We now create another dataframe top_10 which contains the top 10 movies along with their rating sorted in the decreasing order of rating.

# %%
top_10=movieid_rating.sort_values(ascending=False,by="rating").head(10)

# %%
mid=top_10.movie_id

# %%
tags["movieId"].tolist()
# Out:
# [60756,
#  60756,
#  60756,
#  89774,
#  89774,
#  89774,
#  106782,
#  106782,
#  106782,
#  48516,
#  431,
#  431,
#  431,
#  1221,
#  1221,
#  5995,
#  5995,
#  44665,
#  52604,
#  52604,
#  52604,
#  88094,
#  88094,
#  88094,
#  144210,
#  144210,
#  1569,
#  1569,
#  118985,
#  119141,
#  109487,
#  109487,
#  109487,
#  2,
#  2,
#  2,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  110,
#  410,
#  410,
#  410,
#  410,
#  410,
#  410,
#  2023,
#  2023,
#  2023,
#  2023,
#  2023,
#  2124,
#  2124,
#  2124,
#  2124,
#  2124,
#  2124,
#  2953,
#  2953,
#  2953,
#  2953,
#  3114,
#  3114,
#  3114,
#  3114,
#  3114,
#  3114,
#  3114,
#  3578,
#  3578,
#  3578,
#  3578,
#  3578,
#  3578,
#  3578,
#  4223,
#  4223,
#  4223,
#  4223,
#  4223,
#  5388,
#  5388,
#  5388,
#  5388,
#  6058,
#  6058,
#  6534,
#  6534,
#  6534,
#  6534,
#  6541,
#  6541,
#  6541,
#  6541,
#  6541,
#  6541,
#  6564,
#  6564,
#  6564,
#  7153,
#  7153,
#  7153,
#  7153,
#  7153,
#  7153,
#  7153,
#  7153,
#  7153,
#  8641,
#  8641,
#  8641,
#  27660,
#  27660,
#  27660,
#  27660,
#  27660,
#  27660,
#  27706,
#  27706,
#  27706,
#  27706,
#  27706,
#  27808,
#  27808,
#  27808,
#  27831,
#  27831,
#  27831,
#  27831,
#  27831,
#  27831,
#  27831,
#  31658,
#  31658,
#  31658,
#  31658,
#  33162,
#  33162,
#  33162,
#  33162,
#  34150,
#  34150,
#  34150,
#  34150,
#  34150,
#  34150,
#  37729,
#  37729,
#  37729,
#  37729,
#  37729,
#  38061,
#  38061,
#  38061,
#  38061,
#  38061,
#  38061,
#  45447,
#  45447,
#  45447,
#  45447,
#  45447,
#  45447,
#  45447,
#  46723,
#  46723,
#  46723,
#  46723,
#  46972,
#  46972,
#  46976,
#  46976,
#  46976,
#  46976,
#  46976,
#  46976,
#  49130,
#  49530,
#  49530,
#  49530,
#  49530,
#  49530,
#  53464,
#  53464,
#  53464,
#  53464,
#  53464,
#  53464,
#  53464,
#  58047,
#  58047,
#  59501,
#  59501,
#  59501,
#  59501,
#  60074,
#  60074,
#  60074,
#  60126,
#  60126,
#  60756,
#  60756,
#  60756,
#  61024,
#  61024,
#  61024,
#  61024,
#  63992,
#  63992,
#  63992,
#  63992,
#  63992,
#  68848,
#  68848,
#  68848,
#  68848,
#  68848,
#  68848,
#  71535,
#  71535,
#  71535,
#  71535,
#  71535,
#  71535,
#  87430,
#  87430,
#  87430,
#  87430,
#  87430,
#  87430,
#  87430,
#  87430,
#  87430,
#  88405,
#  88405,
#  88405,
#  88405,
#  88405,
#  88405,
#  88405,
#  88405,
#  88405,
#  96861,
#  96861,
#  96861,
#  96861,
#  96861,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  99114,
#  103042,
#  103042,
#  104863,
#  104863,
#  107348,
#  107348,
#  107348,
#  107348,
#  108190,
#  108190,
#  108190,
#  108190,
#  108190,
#  108190,
#  108190,
#  108190,
#  111743,
#  111743,
#  111743,
#  111743,
#  114180,
#  114180,
#  114180,
#  114180,
#  114180,
#  114180,
#  114180,
#  114180,
#  115149,
#  115149,
#  115149,
#  115149,
#  115149,
#  115149,
#  116897,
#  116897,
#  116897,
#  116897,
#  116897,
#  116897,
#  119141,
#  119141,
#  119141,
#  119141,
#  119141,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  122912,
#  128360,
#  128360,
#  128360,
#  128360,
#  128360,
#  128360,
#  128360,
#  128360,
#  128360,
#  135133,
#  135133,
#  135133,
#  135133,
#  135133,
#  135133,
#  135133,
#  135518,
#  135518,
#  135518,
#  135518,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  135536,
#  136864,
#  136864,
#  136864,
#  136864,
#  136864,
#  136864,
#  136864,
#  136864,
#  136864,
#  139385,
#  139385,
#  139385,
#  139385,
#  158966,
#  158966,
#  158966,
#  158966,
#  158966,
#  158966,
#  168248,
#  168248,
#  168248,
#  168248,
#  168248,
#  168248,
#  168248,
#  174053,
#  174053,
#  174053,
#  174053,
#  174053,
#  179401,
#  179401,
#  179401,
#  179401,
#  183611,
#  183611,
#  183611,
#  184471,
#  184471,
#  184471,
#  187593,
#  187593,
#  187593,
#  187595,
#  187595,
#  260,
#  260,
#  260,
#  260,
#  260,
#  260,
#  296,
#  296,
#  296,
#  4896,
#  106489,
#  260,
#  260,
#  260,
#  260,
#  260,
#  101142,
#  101142,
#  101142,
#  115149,
#  115149,
#  115149,
#  115617,
#  115617,
#  115617,
#  120635,
#  120635,
#  120635,
#  1726,
#  1726,
#  2387,
#  2387,
#  3052,
#  3052,
#  3052,
#  3052,
#  5088,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7022,
#  7254,
#  7254,
#  7254,
#  7254,
#  8957,
#  8957,
#  8957,
#  8957,
#  8957,
#  8957,
#  8957,
#  9010,
#  42632,
#  58301,
#  60950,
#  62434,
#  62434,
#  67695,
#  100083,
#  100083,
#  100083,
#  100083,
#  100083,
#  156371,
#  158872,
#  158872,
#  158872,
#  158872,
#  158872,
#  3556,
#  6323,
#  6367,
#  6367,
#  59103,
#  59103,
#  52287,
#  293,
#  293,
#  54286,
#  54286,
#  54286,
#  54286,
#  104,
#  115617,
#  115617,
#  115617,
#  2579,
#  2579,
#  2579,
#  2579,
#  2579,
#  2579,
#  3793,
#  3793,
#  3793,
#  3793,
#  3793,
#  4226,
#  4226,
#  4226,
#  4226,
#  4226,
#  4896,
#  4896,
#  4896,
#  4896,
#  5388,
#  5388,
#  5388,
#  6283,
#  6283,
#  6283,
#  27156,
#  27156,
#  27156,
#  27156,
#  27156,
#  193565,
#  193565,
#  193565,
#  193565,
#  260,
#  260,
#  260,
#  4878,
#  4878,
#  4878,
#  4878,
#  4878,
#  4878,
#  4878,
#  7147,
#  7147,
#  7147,
#  7147,
#  7361,
#  7361,
#  7361,
#  97938,
#  97938,
#  97938,
#  260,
#  260,
#  260,
#  6938,
#  6938,
#  48780,
#  126548,
#  126548,
#  68319,
#  7020,
#  3,
#  3,
#  527,
#  1101,
#  50872,
#  50872,
#  102007,
#  118696,
#  6711,
#  4034,
#  4995,
#  6502,
#  6953,
#  8641,
#  34405,
#  55721,
#  83134,
#  778,
#  778,
#  778,
#  4612,
#  4708,
#  6400,
#  30892,
#  30892,
#  30892,
#  48698,
#  64034,
#  64034,
#  68954,
#  68954,
#  68954,
#  68954,
#  68954,
#  68954,
#  68954,
#  68954,
#  68954,
#  71494,
#  81158,
#  82459,
#  82459,
#  82459,
#  82459,
#  82459,
#  90769,
#  90769,
#  90769,
#  96084,
#  96084,
#  96084,
#  111364,
#  118784,
#  118784,
#  118784,
#  127172,
#  127172,
#  127172,
#  364,
#  364,
#  364,
#  1288,
#  1923,
#  2616,
#  3481,
#  3897,
#  8641,
#  51255,
#  1,
#  153,
#  552,
#  1246,
#  32587,
#  33660,
#  34162,
#  36529,
#  37729,
#  38798,
#  260,
#  260,
#  2146,
#  37384,
#  40955,
#  44889,
#  61323,
#  39,
#  39,
#  39,
#  39,
#  39,
#  1059,
#  1059,
#  1059,
#  1059,
#  2762,
#  2762,
#  2762,
#  2762,
#  2762,
#  2762,
#  2762,
#  4370,
#  4370,
#  4370,
#  4370,
#  5464,
#  5464,
#  7078,
#  7078,
#  7444,
#  7451,
#  7451,
#  7451,
#  48516,
#  48516,
#  48516,
#  48516,
#  54997,
#  55290,
#  55290,
#  55290,
#  91500,
#  91529,
#  91529,
#  91529,
#  91529,
#  91529,
#  91529,
#  91529,
#  91529,
#  98961,
#  98961,
#  98961,
#  98961,
#  98961,
#  32,
#  47,
#  47,
#  50,
#  50,
#  50,
#  50,
#  50,
#  147,
#  147,
#  147,
#  147,
#  175,
#  175,
#  175,
#  223,
#  223,
#  223,
#  223,
#  223,
#  260,
#  260,
#  260,
#  260,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  296,
#  296,
#  296,
#  296,
#  364,
#  527,
#  541,
#  589,
#  589,
#  589,
#  589,
#  589,
#  589,
#  608,
#  608,
#  608,
#  608,
#  628,
#  628,
#  628,
#  628,
#  628,
#  1089,
#  1089,
#  1089,
#  1089,
#  1120,
#  1136,
#  1136,
#  1193,
#  1193,
#  1198,
#  1198,
#  1198,
#  1198,
#  1198,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1219,
#  1219,
#  1219,
#  1219,
#  1240,
#  1240,
#  1240,
#  1240,
#  1240,
#  1240,
#  1240,
#  1258,
#  1258,
#  1258,
#  1258,
#  1258,
#  1258,
#  1258,
#  1258,
#  1343,
#  1343,
#  1343,
#  1343,
#  1625,
#  1625,
#  1625,
#  1625,
#  1625,
#  1625,
#  1704,
#  1921,
#  1921,
#  1921,
#  1921,
#  1923,
#  1923,
#  1923,
#  2160,
#  2160,
#  2160,
#  2160,
#  2160,
#  2296,
#  2329,
#  2505,
#  2571,
#  2571,
#  2700,
#  2700,
#  2700,
#  2700,
#  2700,
#  2700,
#  2700,
#  2700,
#  2959,
#  2959,
#  2959,
#  2959,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3176,
#  3186,
#  3186,
#  3186,
#  3186,
#  3186,
#  3186,
#  3499,
#  3499,
#  3499,
#  3499,
#  3499,
#  3499,
#  3499,
#  3527,
#  3527,
#  3527,
#  3911,
#  3948,
#  3948,
#  4226,
#  4226,
#  4226,
#  4262,
#  4816,
#  4816,
#  4816,
#  4816,
#  4816,
#  4816,
#  4878,
#  4993,
#  4993,
#  4993,
#  4993,
#  4993,
#  4993,
#  5291,
#  5291,
#  6016,
#  6016,
#  6188,
#  6188,
#  6290,
#  7361,
#  8641,
#  8641,
#  8950,
#  8950,
#  8950,
#  8950,
#  8950,
#  8950,
#  27020,
#  27020,
#  30825,
#  30825,
#  34323,
#  40278,
#  40278,
#  48516,
#  48516,
#  48516,
#  48516,
#  48516,
#  53127,
#  53127,
#  53127,
#  53127,
#  53127,
#  53127,
#  60756,
#  60756,
#  66097,
#  66097,
#  66097,
#  66097,
#  66097,
#  66097,
#  68157,
#  68157,
#  68157,
#  68157,
#  68157,
#  74458,
#  74458,
#  74458,
#  74458,
#  74458,
#  74458,
#  74458,
#  79132,
#  79132,
#  79132,
#  79132,
#  79132,
#  79132,
#  81562,
#  81591,
#  81591,
#  81591,
#  81591,
#  81591,
#  81591,
#  102903,
#  102903,
#  102903,
#  102903,
#  104879,
#  104879,
#  104879,
#  104879,
#  104879,
#  104879,
#  104879,
#  104879,
#  106100,
#  106100,
#  106100,
#  106489,
#  106489,
#  106489,
#  109487,
#  109487,
#  109487,
#  112515,
#  112515,
#  112515,
#  112515,
#  112556,
#  112556,
#  750,
#  2959,
#  58559,
#  58559,
#  5952,
#  98809,
#  98809,
#  152711,
#  152711,
#  152711,
#  152711,
#  152711,
#  1,
#  2,
#  5,
#  5,
#  7,
#  11,
#  11,
#  14,
#  14,
#  16,
#  17,
#  21,
#  22,
#  25,
#  26,
#  28,
#  28,
#  29,
#  31,
#  ...]

# %% [markdown]
# ### Importing the movies dataset into dataframe movies.

# %%
movies=pd.read_csv("C:/Users/Administrator/Desktop/machine learning/Assignment3/Assignment3/MovieRating/ml-latest-small/movies.csv")

# %% [markdown]
# ### Printing the first few records.

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# - We are now getting information (movieId,Title,Genres) of only those movies which are present in the top 10 dataframe.

# %%
movies[movies["movieId"].isin(mid)]
# Out:
#       movieId                                  title  \
# 2936     3939       Slumber Party Massacre II (1987)
# 3110     4180             Reform School Girls (1986)
# 3807     5328                            Rain (2001)
# 4372     6402                     Siam Sunset (1999)
# 6410    50999      Ugly Duckling and Me!, The (2006)
# 6495    53280                      Breed, The (2006)
# 7199    72692  Mickey's Once Upon a Christmas (1999)
# 7332    77846                    12 Angry Men (1997)
# 8726   126921         The Fox and the Hound 2 (2006)
# 9194   150554                    The Love Bug (1997)
#
#                                    genres
# 2936                               Horror
# 3110                         Action|Drama
# 3807                        Drama|Romance
# 4372                               Comedy
# 6410                     Animation|Comedy
# 6495                      Horror|Thriller
# 7199             Animation|Comedy|Fantasy
# 7332                          Crime|Drama
# 8726  Adventure|Animation|Children|Comedy
# 9194    Adventure|Children|Comedy|Fantasy

# %% [markdown]
# ### 4.Display the MovieID, IMDB ID, Average User Rating (excluding predictions), genres and tag of all the movies found in Step 3 as a data frame.

# %% [markdown]
# - Reading the links dataset into the dataframe links and printing the first few records.

# %%
links=pd.read_csv("C:/Users/Administrator/Desktop/machine learning/Assignment3/Assignment3/MovieRating/ml-latest-small/links.csv")

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# - Reading the tags dataset into the dataframe tags and printing the first few records.

# %%
tags=pd.read_csv("C:/Users/Administrator/Desktop/machine learning/Assignment3/Assignment3/MovieRating/ml-latest-small/tags.csv")

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %% [markdown]
# - Getting the imbd and the genres of those movies which are in top 10.

# %%
imdb=links[links["movieId"].isin(mid)]["imdbId"].tolist()
genres=movies[movies["movieId"].isin(mid)]["genres"].tolist()

# %% [markdown]
# - We are now getting the average rating of movies which are present among the top 10 movies.

# %%
avg_rating=ratings.groupby("movieId").agg({"rating":np.mean})

# %%
avg_rating
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# ...           ...
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193587   3.500000
# 193609   4.000000
#
# [9724 rows x 1 columns]

# %%
avg=avg_rating[avg_rating.index.isin(mid)]["rating"].tolist()

# %% [markdown]
# - We are now creating a final dataframe which consists of the movieId, the imdb id,the average user rating and the genres of all the movies present among the top 10 to be suggested to the user as per predicted rating greator than 2.5.

# %%
final_df=pd.DataFrame({"Movie ID":mid,"IMDB ID":imdb,"Average User Rating":avg,"Genres":genres})

# %%
final_df
# Out:
#       Movie ID  IMDB ID  Average User Rating  \
# 3295      3939    93996                  5.0
# 7843     53280    91836                  5.0
# 7556     50999   287645                  5.0
# 5063      6402   178022                  5.0
# 9095    126921   396042                  5.0
# 6845     77846   455362                  5.0
# 7711    150554   238414                  5.0
# 4353      5328   118528                  5.0
# 5590     72692   465997                  5.0
# 3498      4180   119571                  5.0
#
#                                    Genres
# 3295                               Horror
# 7843                         Action|Drama
# 7556                        Drama|Romance
# 5063                               Comedy
# 9095                     Animation|Comedy
# 6845                      Horror|Thriller
# 7711             Animation|Comedy|Fantasy
# 4353                          Crime|Drama
# 5590  Adventure|Animation|Children|Comedy
# 3498    Adventure|Children|Comedy|Fantasy

# %% [markdown]
# ### Summary of tasks
# - Importing required libraries and loading the input datasets.
# - Creating a recommender system using the ratings.csv file
# - First we set the rating scake and then consider only required columns for our final dataset.
# - Splitting the dataset into training and testing sets.
# - Creating a recommendation model with KNNWithMeans taking 50 as the maximum number of neighbours for aggregation.
# - Testing the fitted model on the testset.
# - calculating the Rmse of the model.
# - displaying predicted user rating for a particular user and movie combinations.
# - Recommending a user to watch top 10 movies which he has not watched yet , based on his predicted rating and considering the value as above 2.5.
# - To do the above task we find the list of movies not watched by the user.
# - we then predict the rating the user would give for those movies.
# - Based on the rating we sort the movies in descending order and consider only the top 10 movies.
# - Later, we import other datasets to get the genre, imbd and average user rating for each of those 10 movies.
